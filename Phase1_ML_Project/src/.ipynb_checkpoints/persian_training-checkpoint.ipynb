# %%
import nltk, string, re, os, numpy, math
from nltk import *
from nltk.stem import WordNetLemmatizer
from __future__ import unicode_literals
from hazm import *
#nltk.download('punkt') # uncomment the following two lines(including this line) if it is your first time running this code 
#nltk.download('wordnet')

# %%
#this function will help us throuhg cleanign the texts so we can find the stop words. It has 
normalizer = Normalizer()
lemmatizer = Lemmatizer()
def clean_text(sentence):
    sentence = normalizer.normalize(sentence)
    tokens = nltk.word_tokenize(sentence)
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
sentence = input("Enter the sentence you want to be cleaned:")
sentence = ' '.join(clean_text(sentence))
print(sentence)
# Out:
# Enter the sentence you want to be cleaned:میلاد سلام رسوند
# میلاد سلام رسوند

# %%
#building a dictionary
path = "../data/PersianData"
dic = {}
for file in os.listdir(path):
    filename = os.path.join(path, file)
    with open(filename) as f:
        print(filename)
        s = f.readlines()
        s = ' '.join(s) 
        tks = clean_text(s)
        for tk in tks:
            if tk in dic:
                dic[tk] = dic[tk]+1
            else:
                dic[tk] = 1

#find the stop words based on their frequency in the document
freq = sorted(dic.items(), key = lambda kv:-kv[1])
stop_words = [kv[0] for kv in freq[1:50]]
# Out:
# ../data/PersianData/HAM2-840903-068.ham
# ../data/PersianData/HAM2-840804-083.ham
# ../data/PersianData/HAM2-840930-005.ham
# ../data/PersianData/HAM2-840915-103.ham
# ../data/PersianData/HAM2-840505-017.ham
# ../data/PersianData/HAM2-840318-038.ham
# ../data/PersianData/HAM2-840921-018.ham
# ../data/PersianData/HAM2-840721-069.ham
# ../data/PersianData/HAM2-840305-129.ham
# ../data/PersianData/HAM2-840921-065.ham
# ../data/PersianData/HAM2-840624-170.ham
# ../data/PersianData/HAM2-840811-057.ham
# ../data/PersianData/HAM2-840218-011.ham
# ../data/PersianData/HAM2-841001-153.ham
# ../data/PersianData/HAM2-840825-048.ham
# ../data/PersianData/HAM2-840804-003.ham
# ../data/PersianData/HAM2-840302-009.ham
# ../data/PersianData/HAM2-840512-112.ham
# ../data/PersianData/HAM2-840707-129.ham
# ../data/PersianData/HAM2-840818-010.ham
# ../data/PersianData/HAM2-840505-174.ham
# ../data/PersianData/HAM2-840510-083.ham
# ../data/PersianData/HAM2-840330-086.ham
# ../data/PersianData/HAM2-840920-116.ham
# ../data/PersianData/HAM2-840525-122.ham
# ../data/PersianData/HAM2-840321-094.ham
# ../data/PersianData/HAM2-840720-132.ham
# ../data/PersianData/HAM2-840606-028.ham
# ../data/PersianData/HAM2-840724-066.ham
# ../data/PersianData/HAM2-840804-039.ham
# ../data/PersianData/HAM2-840408-104.ham
# ../data/PersianData/HAM2-840714-126.ham
# ../data/PersianData/HAM2-840208-123.ham
# ../data/PersianData/HAM2-840602-084.ham
# ../data/PersianData/HAM2-840329-093.ham
# ../data/PersianData/HAM2-840909-039.ham
# ../data/PersianData/HAM2-840804-164.ham
# ../data/PersianData/HAM2-840713-057.ham
# ../data/PersianData/HAM2-840702-084.ham
# ../data/PersianData/HAM2-840804-188.ham
# ../data/PersianData/HAM2-840913-033.ham
# ../data/PersianData/HAM2-840814-036.ham
# ../data/PersianData/HAM2-840826-002.ham
# ../data/PersianData/HAM2-840401-119.ham
# ../data/PersianData/HAM2-840506-173.ham
# ../data/PersianData/HAM2-840926-078.ham
# ../data/PersianData/HAM2-840421-090.ham
# ../data/PersianData/HAM2-840602-093.ham
# ../data/PersianData/HAM2-840926-007.ham
# ../data/PersianData/HAM2-840713-131.ham
# ../data/PersianData/HAM2-840914-020.ham
# ../data/PersianData/HAM2-840718-058.ham
# ../data/PersianData/HAM2-840902-069.ham
# ../data/PersianData/HAM2-840818-114.ham
# ../data/PersianData/HAM2-840529-007.ham
# ../data/PersianData/HAM2-840330-036.ham
# ../data/PersianData/HAM2-840506-139.ham
# ../data/PersianData/HAM2-841001-141.ham
# ../data/PersianData/HAM2-840517-048.ham
# ../data/PersianData/HAM2-840326-073.ham
# ../data/PersianData/HAM2-840828-009.ham
# ../data/PersianData/HAM2-840517-072.ham
# ../data/PersianData/HAM2-840508-003.ham
# ../data/PersianData/HAM2-841010-019.ham
# ../data/PersianData/HAM2-840704-051.ham
# ../data/PersianData/HAM2-840601-010.ham
# ../data/PersianData/HAM2-840422-127.ham
# ../data/PersianData/HAM2-840226-057.ham
# ../data/PersianData/HAM2-840802-127.ham
# ../data/PersianData/HAM2-840422-100.ham
# ../data/PersianData/HAM2-840707-117.ham
# ../data/PersianData/HAM2-840303-013.ham
# ../data/PersianData/HAM2-840624-053.ham
# ../data/PersianData/HAM2-840415-003.ham
# ../data/PersianData/HAM2-840717-031.ham
# ../data/PersianData/HAM2-840714-052.ham
# ../data/PersianData/HAM2-840324-056.ham
# ../data/PersianData/HAM2-840326-081.ham
# ../data/PersianData/HAM2-840416-095.ham
# ../data/PersianData/HAM2-840930-041.ham
# ../data/PersianData/HAM2-840517-001.ham
# ../data/PersianData/HAM2-840603-076.ham
# ../data/PersianData/HAM2-840530-034.ham
# ../data/PersianData/HAM2-840630-034.ham
# ../data/PersianData/HAM2-840908-136.ham
# ../data/PersianData/HAM2-840430-192.ham
# ../data/PersianData/HAM2-840217-124.ham
# ../data/PersianData/HAM2-840928-135.ham
# ../data/PersianData/HAM2-840319-132.ham
# ../data/PersianData/HAM2-840924-095.ham
# ../data/PersianData/HAM2-840319-014.ham
# ../data/PersianData/HAM2-840607-054.ham
# ../data/PersianData/HAM2-840506-190.ham
# ../data/PersianData/HAM2-840725-151.ham
# ../data/PersianData/HAM2-840221-097.ham
# ../data/PersianData/HAM2-840927-035.ham
# ../data/PersianData/HAM2-840723-142.ham
# ../data/PersianData/HAM2-840901-095.ham
# ../data/PersianData/HAM2-840601-081.ham
# ../data/PersianData/HAM2-840705-042.ham
# ../data/PersianData/HAM2-840809-124.ham
# ../data/PersianData/HAM2-840324-019.ham
# ../data/PersianData/HAM2-840821-010.ham
# ../data/PersianData/HAM2-840430-063.ham
# ../data/PersianData/HAM2-840407-025.ham
# ../data/PersianData/HAM2-840225-092.ham
# ../data/PersianData/HAM2-840530-082.ham
# ../data/PersianData/HAM2-840220-096.ham
# ../data/PersianData/HAM2-841010-026.ham
# ../data/PersianData/HAM2-840909-093.ham
# ../data/PersianData/HAM2-840821-081.ham
# ../data/PersianData/HAM2-840406-005.ham
# ../data/PersianData/HAM2-840406-002.ham
# ../data/PersianData/HAM2-840808-003.ham
# ../data/PersianData/HAM2-840902-140.ham
# ../data/PersianData/HAM2-840616-072.ham
# ../data/PersianData/HAM2-840203-011.ham
# ../data/PersianData/HAM2-840217-001.ham
# ../data/PersianData/HAM2-840714-075.ham
# ../data/PersianData/HAM2-840422-044.ham
# ../data/PersianData/HAM2-840426-051.ham
# ../data/PersianData/HAM2-840203-043.ham
# ../data/PersianData/HAM2-840901-108.ham
# ../data/PersianData/HAM2-840412-091.ham
# ../data/PersianData/HAM2-840602-033.ham
# ../data/PersianData/HAM2-840520-120.ham
# ../data/PersianData/HAM2-840706-030.ham
# ../data/PersianData/HAM2-840909-067.ham
# ../data/PersianData/HAM2-840714-062.ham
# ../data/PersianData/HAM2-840322-052.ham
# ../data/PersianData/HAM2-840624-107.ham
# ../data/PersianData/HAM2-840704-103.ham
# ../data/PersianData/HAM2-840213-022.ham
# ../data/PersianData/HAM2-840301-035.ham
# ../data/PersianData/HAM2-840218-059.ham
# ../data/PersianData/HAM2-840811-016.ham
# ../data/PersianData/HAM2-840610-002.ham
# ../data/PersianData/HAM2-840817-071.ham
# ../data/PersianData/HAM2-840702-029.ham
# ../data/PersianData/HAM2-840725-079.ham
# ../data/PersianData/HAM2-840214-024.ham
# ../data/PersianData/HAM2-840724-058.ham
# ../data/PersianData/HAM2-840211-060.ham
# ../data/PersianData/HAM2-840525-035.ham
# ../data/PersianData/HAM2-840603-163.ham
# ../data/PersianData/HAM2-840615-142.ham
# ../data/PersianData/HAM2-840706-003.ham
# ../data/PersianData/HAM2-840804-025.ham
# ../data/PersianData/HAM2-840826-130.ham
# ../data/PersianData/HAM2-840712-039.ham
# ../data/PersianData/HAM2-840704-071.ham
# ../data/PersianData/HAM2-840219-007.ham
# ../data/PersianData/HAM2-840511-065.ham
# ../data/PersianData/HAM2-840324-095.ham
# ../data/PersianData/HAM2-840322-048.ham
# ../data/PersianData/HAM2-841006-103.ham
# ../data/PersianData/HAM2-840516-051.ham
# ../data/PersianData/HAM2-840402-081.ham
# ../data/PersianData/HAM2-840430-076.ham
# ../data/PersianData/HAM2-840815-048.ham
# ../data/PersianData/HAM2-840319-120.ham
# ../data/PersianData/HAM2-840705-115.ham
# ../data/PersianData/HAM2-841008-043.ham
# ../data/PersianData/HAM2-840721-115.ham
# ../data/PersianData/HAM2-840807-033.ham
# ../data/PersianData/HAM2-840718-016.ham
# ../data/PersianData/HAM2-840719-109.ham
# ../data/PersianData/HAM2-840221-064.ham
# ../data/PersianData/HAM2-840913-050.ham
# ../data/PersianData/HAM2-840215-167.ham
# ../data/PersianData/HAM2-840705-124.ham
# ../data/PersianData/HAM2-840719-033.ham
# ../data/PersianData/HAM2-840211-121.ham
# ../data/PersianData/HAM2-840608-089.ham
# ../data/PersianData/HAM2-840214-015.ham
# ../data/PersianData/HAM2-840916-127.ham
# ../data/PersianData/HAM2-840814-079.ham
# ../data/PersianData/HAM2-841005-098.ham
# ../data/PersianData/HAM2-840727-176.ham
# ../data/PersianData/HAM2-840423-024.ham
# ../data/PersianData/HAM2-841004-099.ham
# ../data/PersianData/HAM2-840330-075.ham
# ../data/PersianData/HAM2-840910-180.ham
# ../data/PersianData/HAM2-840910-014.ham
# ../data/PersianData/HAM2-840910-146.ham
# ../data/PersianData/HAM2-840231-080.ham
# ../data/PersianData/HAM2-840523-020.ham
# ../data/PersianData/HAM2-840326-118.ham
# ../data/PersianData/HAM2-841007-022.ham
# ../data/PersianData/HAM2-840626-076.ham
# ../data/PersianData/HAM2-840817-162.ham
# ../data/PersianData/HAM2-840829-063.ham
# ../data/PersianData/HAM2-840616-003.ham
# ../data/PersianData/HAM2-840303-074.ham
# ../data/PersianData/HAM2-831012-017.ham
# ../data/PersianData/HAM2-840408-125.ham
# ../data/PersianData/HAM2-840425-037.ham
# ../data/PersianData/HAM2-840823-061.ham
# ../data/PersianData/HAM2-840429-071.ham
# ../data/PersianData/HAM2-840815-086.ham
# ../data/PersianData/HAM2-840930-050.ham
# ../data/PersianData/HAM2-840824-043.ham
# ../data/PersianData/HAM2-840409-157.ham
# ../data/PersianData/HAM2-840810-055.ham
# ../data/PersianData/HAM2-840605-029.ham
# ../data/PersianData/HAM2-840814-013.ham
# ../data/PersianData/HAM2-840825-012.ham
# ../data/PersianData/HAM2-840524-089.ham
# ../data/PersianData/HAM2-840423-102.ham
# ../data/PersianData/HAM2-840809-037.ham
# ../data/PersianData/HAM2-840615-042.ham
# ../data/PersianData/HAM2-840316-121.ham
# ../data/PersianData/HAM2-840816-061.ham
# ../data/PersianData/HAM2-840826-049.ham
# ../data/PersianData/HAM2-840225-082.ham
# ../data/PersianData/HAM2-840808-169.ham
# ../data/PersianData/HAM2-840428-041.ham
# ../data/PersianData/HAM2-840704-008.ham
# ../data/PersianData/HAM2-840922-007.ham
# ../data/PersianData/HAM2-840710-126.ham
# ../data/PersianData/HAM2-840323-030.ham
# ../data/PersianData/HAM2-841003-041.ham
# ../data/PersianData/HAM2-840807-016.ham
# ../data/PersianData/HAM2-840530-008.ham
# ../data/PersianData/HAM2-840422-005.ham
# ../data/PersianData/HAM2-840610-121.ham
# ../data/PersianData/HAM2-840429-078.ham
# ../data/PersianData/HAM2-840811-111.ham
# ../data/PersianData/HAM2-840324-073.ham
# ../data/PersianData/HAM2-840406-124.ham
# ../data/PersianData/HAM2-840804-103.ham
# ../data/PersianData/HAM2-840301-146.ham
# ../data/PersianData/HAM2-840930-067.ham
# ../data/PersianData/HAM2-840401-057.ham
# ../data/PersianData/HAM2-841006-102.ham
# ../data/PersianData/HAM2-840527-007.ham
# ../data/PersianData/HAM2-840616-044.ham
# ../data/PersianData/HAM2-840920-012.ham
# ../data/PersianData/HAM2-840913-123.ham
# ../data/PersianData/HAM2-840312-012.ham
# ../data/PersianData/HAM2-840519-042.ham
# ../data/PersianData/HAM2-840627-015.ham
# ../data/PersianData/HAM2-840619-070.ham
# ../data/PersianData/HAM2-840703-005.ham
# ../data/PersianData/HAM2-840910-130.ham
# ../data/PersianData/HAM2-840515-089.ham
# ../data/PersianData/HAM2-840903-022.ham
# ../data/PersianData/HAM2-840703-062.ham
# ../data/PersianData/HAM2-840612-027.ham
# ../data/PersianData/HAM2-840824-039.ham
# ../data/PersianData/HAM2-840511-011.ham
# ../data/PersianData/HAM2-840504-092.ham
# ../data/PersianData/HAM2-840822-033.ham
# ../data/PersianData/HAM2-840622-133.ham
# ../data/PersianData/HAM2-841006-006.ham
# ../data/PersianData/HAM2-840608-080.ham
# ../data/PersianData/HAM2-840815-041.ham
# ../data/PersianData/HAM2-840508-128.ham
# ../data/PersianData/HAM2-840520-047.ham
# ../data/PersianData/HAM2-840617-009.ham
# ../data/PersianData/HAM2-840614-018.ham
# ../data/PersianData/HAM2-840231-062.ham
# ../data/PersianData/HAM2-840719-086.ham
# ../data/PersianData/HAM2-840531-026.ham
# ../data/PersianData/HAM2-840305-139.ham
# ../data/PersianData/HAM2-840713-034.ham
# ../data/PersianData/HAM2-840208-044.ham
# ../data/PersianData/HAM2-840511-043.ham
# ../data/PersianData/HAM2-840728-057.ham
# ../data/PersianData/HAM2-841003-021.ham
# ../data/PersianData/HAM2-840321-118.ham
# ../data/PersianData/HAM2-840222-054.ham
# ../data/PersianData/HAM2-840709-096.ham
# ../data/PersianData/HAM2-840422-098.ham
# ../data/PersianData/HAM2-840523-048.ham
# ../data/PersianData/HAM2-840525-010.ham
# ../data/PersianData/HAM2-840303-003.ham
# ../data/PersianData/HAM2-841007-099.ham
# ../data/PersianData/HAM2-840613-163.ham
# ../data/PersianData/HAM2-840503-068.ham
# ../data/PersianData/HAM2-840605-001.ham
# ../data/PersianData/HAM2-840421-094.ham
# ../data/PersianData/HAM2-840221-005.ham
# ../data/PersianData/HAM2-840508-066.ham
# ../data/PersianData/HAM2-840418-002.ham
# ../data/PersianData/HAM2-840901-086.ham
# ../data/PersianData/HAM2-840630-019.ham
# ../data/PersianData/HAM2-840919-088.ham
# ../data/PersianData/HAM2-840610-069.ham
# ../data/PersianData/HAM2-840502-110.ham
# ../data/PersianData/HAM2-840716-036.ham
# ../data/PersianData/HAM2-840214-110.ham
# ../data/PersianData/HAM2-840710-127.ham
# ../data/PersianData/HAM2-840518-045.ham
# ../data/PersianData/HAM2-840519-141.ham
# ../data/PersianData/HAM2-840816-055.ham
# ../data/PersianData/HAM2-840503-059.ham
# ../data/PersianData/HAM2-840614-133.ham
# ../data/PersianData/HAM2-840316-127.ham
# ../data/PersianData/HAM2-840301-145.ham
# ../data/PersianData/HAM2-840727-067.ham
# ../data/PersianData/HAM2-840527-005.ham
# ../data/PersianData/HAM2-840512-116.ham
# ../data/PersianData/HAM2-840522-046.ham
# ../data/PersianData/HAM2-840807-056.ham
# ../data/PersianData/HAM2-840822-128.ham
# ../data/PersianData/HAM2-840607-114.ham
# ../data/PersianData/HAM2-840808-046.ham
# ../data/PersianData/HAM2-840916-135.ham
# ../data/PersianData/HAM2-840215-097.ham
# ../data/PersianData/HAM2-840215-103.ham
# ../data/PersianData/HAM2-840829-085.ham
# ../data/PersianData/HAM2-840802-005.ham
# ../data/PersianData/HAM2-840830-133.ham
# ../data/PersianData/HAM2-840527-171.ham
# ../data/PersianData/HAM2-840617-055.ham
# ../data/PersianData/HAM2-840712-033.ham
# ../data/PersianData/HAM2-840509-096.ham
# ../data/PersianData/HAM2-840428-072.ham
# ../data/PersianData/HAM2-840705-073.ham
# ../data/PersianData/HAM2-840524-058.ham
# ../data/PersianData/HAM2-840807-003.ham
# ../data/PersianData/HAM2-840721-023.ham
# ../data/PersianData/HAM2-840622-101.ham
# ../data/PersianData/HAM2-840811-062.ham
# ../data/PersianData/HAM2-840914-074.ham
# ../data/PersianData/HAM2-840413-102.ham
# ../data/PersianData/HAM2-840408-102.ham
# ../data/PersianData/HAM2-840624-083.ham
# ../data/PersianData/HAM2-840227-073.ham
# ../data/PersianData/HAM2-840412-032.ham
# ../data/PersianData/HAM2-840318-026.ham
# ../data/PersianData/HAM2-840515-023.ham
# ../data/PersianData/HAM2-840727-103.ham
# ../data/PersianData/HAM2-840823-004.ham
# ../data/PersianData/HAM2-840221-121.ham
# ../data/PersianData/HAM2-840905-042.ham
# ../data/PersianData/HAM2-840530-063.ham
# ../data/PersianData/HAM2-840318-055.ham
# ../data/PersianData/HAM2-840421-054.ham
# ../data/PersianData/HAM2-840520-182.ham
# ../data/PersianData/HAM2-840527-086.ham
# ../data/PersianData/HAM2-841007-142.ham
# ../data/PersianData/HAM2-840901-047.ham
# ../data/PersianData/HAM2-840917-060.ham
# ../data/PersianData/HAM2-840807-072.ham
# ../data/PersianData/HAM2-840819-144.ham
# ../data/PersianData/HAM2-840631-105.ham
# ../data/PersianData/HAM2-840804-076.ham
# ../data/PersianData/HAM2-840817-086.ham
# ../data/PersianData/HAM2-840321-054.ham
# ../data/PersianData/HAM2-840517-163.ham
# ../data/PersianData/HAM2-840411-026.ham
# ../data/PersianData/HAM2-840311-158.ham
# ../data/PersianData/HAM2-840505-065.ham
# ../data/PersianData/HAM2-840805-070.ham
# ../data/PersianData/HAM2-840322-056.ham
# ../data/PersianData/HAM2-840401-060.ham
# ../data/PersianData/HAM2-840828-066.ham
# ../data/PersianData/HAM2-840518-086.ham
# ../data/PersianData/HAM2-840203-010.ham
# ../data/PersianData/HAM2-840623-162.ham
# ../data/PersianData/HAM2-840804-141.ham
# ../data/PersianData/HAM2-840504-097.ham
# ../data/PersianData/HAM2-840217-014.ham
# ../data/PersianData/HAM2-840428-067.ham
# ../data/PersianData/HAM2-840219-085.ham
# ../data/PersianData/HAM2-840825-120.ham
# ../data/PersianData/HAM2-840404-114.ham
# ../data/PersianData/HAM2-840810-029.ham
# ../data/PersianData/HAM2-840331-061.ham
# ../data/PersianData/HAM2-840917-020.ham
# ../data/PersianData/HAM2-840301-038.ham
# ../data/PersianData/HAM2-840301-012.ham
# ../data/PersianData/HAM2-840711-097.ham
# ../data/PersianData/HAM2-840426-151.ham
# ../data/PersianData/HAM2-840505-095.ham
# ../data/PersianData/HAM2-840719-067.ham
# ../data/PersianData/HAM2-840926-052.ham
# ../data/PersianData/HAM2-840623-096.ham
# ../data/PersianData/HAM2-840304-055.ham
# ../data/PersianData/HAM2-840213-079.ham
# ../data/PersianData/HAM2-840325-019.ham
# ../data/PersianData/HAM2-840823-095.ham
# ../data/PersianData/HAM2-840616-153.ham
# ../data/PersianData/HAM2-840422-010.ham
# ../data/PersianData/HAM2-840219-015.ham
# ../data/PersianData/HAM2-840807-110.ham
# ../data/PersianData/HAM2-840418-052.ham
# ../data/PersianData/HAM2-840326-037.ham
# ../data/PersianData/HAM2-840728-109.ham
# ../data/PersianData/HAM2-840810-062.ham
# ../data/PersianData/HAM2-840823-042.ham
# ../data/PersianData/HAM2-840609-111.ham
# ../data/PersianData/HAM2-840509-087.ham
# ../data/PersianData/HAM2-840218-083.ham
# ../data/PersianData/HAM2-840312-099.ham
# ../data/PersianData/HAM2-840516-059.ham
# ../data/PersianData/HAM2-840215-110.ham
# ../data/PersianData/HAM2-840706-105.ham
# ../data/PersianData/HAM2-841007-030.ham
# ../data/PersianData/HAM2-840822-051.ham
# ../data/PersianData/HAM2-840720-096.ham
# ../data/PersianData/HAM2-840631-077.ham
# ../data/PersianData/HAM2-841006-117.ham
# ../data/PersianData/HAM2-841008-142.ham
# ../data/PersianData/HAM2-840613-027.ham
# ../data/PersianData/HAM2-840614-149.ham
# ../data/PersianData/HAM2-840318-109.ham
# ../data/PersianData/HAM2-841004-006.ham
# ../data/PersianData/HAM2-841001-174.ham
# ../data/PersianData/HAM2-840610-114.ham
# ../data/PersianData/HAM2-840301-006.ham
# ../data/PersianData/HAM2-840508-106.ham
# ../data/PersianData/HAM2-840224-034.ham
# ../data/PersianData/HAM2-840923-089.ham
# ../data/PersianData/HAM2-840725-001.ham
# ../data/PersianData/HAM2-840801-102.ham
# ../data/PersianData/HAM2-840322-078.ham
# ../data/PersianData/HAM2-840819-074.ham
# ../data/PersianData/HAM2-840606-070.ham
# ../data/PersianData/HAM2-840331-097.ham
# ../data/PersianData/HAM2-840724-070.ham
# ../data/PersianData/HAM2-840909-139.ham
# ../data/PersianData/HAM2-840617-112.ham
# ../data/PersianData/HAM2-840401-140.ham
# ../data/PersianData/HAM2-840518-066.ham
# ../data/PersianData/HAM2-840422-081.ham
# ../data/PersianData/HAM2-840212-046.ham
# ../data/PersianData/HAM2-840319-030.ham
# ../data/PersianData/HAM2-840725-071.ham
# ../data/PersianData/HAM2-840622-113.ham
# ../data/PersianData/HAM2-841001-089.ham
# ../data/PersianData/HAM2-840624-137.ham
# ../data/PersianData/HAM2-840802-165.ham
# ../data/PersianData/HAM2-840713-095.ham
# ../data/PersianData/HAM2-840906-062.ham
# ../data/PersianData/HAM2-840427-062.ham
# ../data/PersianData/HAM2-840304-056.ham
# ../data/PersianData/HAM2-840926-100.ham
# ../data/PersianData/HAM2-840619-113.ham
# ../data/PersianData/HAM2-840305-008.ham
# ../data/PersianData/HAM2-840516-087.ham
# ../data/PersianData/HAM2-840928-048.ham
# ../data/PersianData/HAM2-840819-153.ham
# ../data/PersianData/HAM2-840427-027.ham
# ../data/PersianData/HAM2-840608-109.ham
# ../data/PersianData/HAM2-840411-012.ham
# ../data/PersianData/HAM2-840826-073.ham
# ../data/PersianData/HAM2-840623-123.ham
# ../data/PersianData/HAM2-840605-141.ham
# ../data/PersianData/HAM2-840305-113.ham
# ../data/PersianData/HAM2-840710-076.ham
# ../data/PersianData/HAM2-840717-169.ham
# ../data/PersianData/HAM2-840529-129.ham
# ../data/PersianData/HAM2-840822-031.ham
# ../data/PersianData/HAM2-840418-132.ham
# ../data/PersianData/HAM2-840229-128.ham
# ../data/PersianData/HAM2-840325-088.ham
# ../data/PersianData/HAM2-840326-097.ham
# ../data/PersianData/HAM2-840808-165.ham
# ../data/PersianData/HAM2-840231-058.ham
# ../data/PersianData/HAM2-840401-156.ham
# ../data/PersianData/HAM2-840826-095.ham
# ../data/PersianData/HAM2-840808-091.ham
# ../data/PersianData/HAM2-840619-062.ham
# ../data/PersianData/HAM2-840908-152.ham
# ../data/PersianData/HAM2-840608-104.ham
# ../data/PersianData/HAM2-840815-062.ham
# ../data/PersianData/HAM2-840224-037.ham
# ../data/PersianData/HAM2-840408-090.ham
# ../data/PersianData/HAM2-840602-042.ham
# ../data/PersianData/HAM2-840513-149.ham
# ../data/PersianData/HAM2-840819-082.ham
# ../data/PersianData/HAM2-840807-023.ham
# ../data/PersianData/HAM2-840225-019.ham
# ../data/PersianData/HAM2-840713-107.ham
# ../data/PersianData/HAM2-840916-027.ham
# ../data/PersianData/HAM2-840226-110.ham
# ../data/PersianData/HAM2-840810-097.ham
# ../data/PersianData/HAM2-840316-015.ham
# ../data/PersianData/HAM2-840822-138.ham
# ../data/PersianData/HAM2-840920-028.ham
# ../data/PersianData/HAM2-840317-016.ham
# ../data/PersianData/HAM2-840412-039.ham
# ../data/PersianData/HAM2-840330-029.ham
# ../data/PersianData/HAM2-841001-117.ham
# ../data/PersianData/HAM2-841008-051.ham
# ../data/PersianData/HAM2-840512-128.ham
# ../data/PersianData/HAM2-840901-109.ham
# ../data/PersianData/HAM2-840322-031.ham
# ../data/PersianData/HAM2-840219-030.ham
# ../data/PersianData/HAM2-840520-087.ham
# ../data/PersianData/HAM2-841006-052.ham
# ../data/PersianData/HAM2-840621-105.ham
# ../data/PersianData/HAM2-840429-158.ham
# ../data/PersianData/HAM2-840802-137.ham
# ../data/PersianData/HAM2-840920-111.ham
# ../data/PersianData/HAM2-840818-095.ham
# ../data/PersianData/HAM2-840518-115.ham
# ../data/PersianData/HAM2-840817-067.ham
# ../data/PersianData/HAM2-840213-055.ham
# ../data/PersianData/HAM2-840913-128.ham
# ../data/PersianData/HAM2-840606-019.ham
# ../data/PersianData/HAM2-840730-005.ham
# ../data/PersianData/HAM2-841006-049.ham
# ../data/PersianData/HAM2-840817-143.ham
# ../data/PersianData/HAM2-841006-155.ham
# ../data/PersianData/HAM2-840513-128.ham
# ../data/PersianData/HAM2-840920-121.ham
# ../data/PersianData/HAM2-840622-025.ham
# ../data/PersianData/HAM2-840303-102.ham
# ../data/PersianData/HAM2-840710-056.ham
# ../data/PersianData/HAM2-840707-043.ham
# ../data/PersianData/HAM2-840526-132.ham
# ../data/PersianData/HAM2-840714-043.ham
# ../data/PersianData/HAM2-840525-067.ham
# ../data/PersianData/HAM2-840318-011.ham
# ../data/PersianData/HAM2-840716-139.ham
# ../data/PersianData/HAM2-840825-079.ham
# ../data/PersianData/HAM2-840407-092.ham
# ../data/PersianData/HAM2-840608-069.ham
# ../data/PersianData/HAM2-840331-048.ham
# ../data/PersianData/HAM2-840713-166.ham
# ../data/PersianData/HAM2-840531-157.ham
# ../data/PersianData/HAM2-840602-175.ham
# ../data/PersianData/HAM2-840409-037.ham
# ../data/PersianData/HAM2-840225-125.ham
# ../data/PersianData/HAM2-840921-116.ham
# ../data/PersianData/HAM2-840724-039.ham
# ../data/PersianData/HAM2-840215-169.ham
# ../data/PersianData/HAM2-840312-106.ham
# ../data/PersianData/HAM2-840824-090.ham
# ../data/PersianData/HAM2-840409-002.ham
# ../data/PersianData/HAM2-840304-059.ham
# ../data/PersianData/HAM2-840905-028.ham
# ../data/PersianData/HAM2-840606-082.ham
# ../data/PersianData/HAM2-840330-152.ham
# ../data/PersianData/HAM2-840928-125.ham
# ../data/PersianData/HAM2-840815-014.ham
# ../data/PersianData/HAM2-840328-110.ham
# ../data/PersianData/HAM2-840603-097.ham
# ../data/PersianData/HAM2-841004-162.ham
# ../data/PersianData/HAM2-840413-147.ham
# ../data/PersianData/HAM2-840711-109.ham
# ../data/PersianData/HAM2-840414-021.ham
# ../data/PersianData/HAM2-840726-010.ham
# ../data/PersianData/HAM2-840522-027.ham
# ../data/PersianData/HAM2-840910-112.ham
# ../data/PersianData/HAM2-840808-025.ham
# ../data/PersianData/HAM2-840309-143.ham
# ../data/PersianData/HAM2-840804-012.ham
# ../data/PersianData/HAM2-840810-088.ham
# ../data/PersianData/HAM2-840214-019.ham
# ../data/PersianData/HAM2-840309-067.ham
# ../data/PersianData/HAM2-840624-190.ham
# ../data/PersianData/HAM2-840418-090.ham
# ../data/PersianData/HAM2-840807-098.ham
# ../data/PersianData/HAM2-840628-026.ham
# ../data/PersianData/HAM2-840703-124.ham
# ../data/PersianData/HAM2-840330-028.ham
# ../data/PersianData/HAM2-840814-060.ham
# ../data/PersianData/HAM2-840607-146.ham
# ../data/PersianData/HAM2-840318-039.ham
# ../data/PersianData/HAM2-840620-003.ham
# ../data/PersianData/HAM2-840502-090.ham
# ../data/PersianData/HAM2-840308-044.ham
# ../data/PersianData/HAM2-840515-098.ham
# ../data/PersianData/HAM2-840427-150.ham
# ../data/PersianData/HAM2-840622-006.ham
# ../data/PersianData/HAM2-840416-147.ham
# ../data/PersianData/HAM2-840805-058.ham
# ../data/PersianData/HAM2-840219-051.ham
# ../data/PersianData/HAM2-840416-139.ham
# ../data/PersianData/HAM2-840608-048.ham
# ../data/PersianData/HAM2-840724-087.ham
# ../data/PersianData/HAM2-840218-091.ham
# ../data/PersianData/HAM2-840713-108.ham
# ../data/PersianData/HAM2-840402-089.ham
# ../data/PersianData/HAM2-840203-068.ham
# ../data/PersianData/HAM2-840905-062.ham
# ../data/PersianData/HAM2-840713-067.ham
# ../data/PersianData/HAM2-840420-116.ham
# ../data/PersianData/HAM2-840401-106.ham
# ../data/PersianData/HAM2-841007-042.ham
# ../data/PersianData/HAM2-840614-129.ham
# ../data/PersianData/HAM2-840926-116.ham
# ../data/PersianData/HAM2-840220-113.ham
# ../data/PersianData/HAM2-840929-124.ham
# ../data/PersianData/HAM2-840322-100.ham
# ../data/PersianData/HAM2-840620-048.ham
# ../data/PersianData/HAM2-840801-165.ham
# ../data/PersianData/HAM2-840808-107.ham
# ../data/PersianData/HAM2-840914-128.ham
# ../data/PersianData/HAM2-840614-001.ham
# ../data/PersianData/HAM2-840312-123.ham
# ../data/PersianData/HAM2-840402-116.ham
# ../data/PersianData/HAM2-840612-144.ham
# ../data/PersianData/HAM2-840809-086.ham
# ../data/PersianData/HAM2-840631-005.ham
# ../data/PersianData/HAM2-840318-053.ham
# ../data/PersianData/HAM2-840603-054.ham
# ../data/PersianData/HAM2-840810-050.ham
# ../data/PersianData/HAM2-840406-045.ham
# ../data/PersianData/HAM2-840816-089.ham
# ../data/PersianData/HAM2-840716-115.ham
# ../data/PersianData/HAM2-840822-022.ham
# ../data/PersianData/HAM2-840703-056.ham
# ../data/PersianData/HAM2-840709-044.ham
# ../data/PersianData/HAM2-840819-020.ham
# ../data/PersianData/HAM2-840817-035.ham
# ../data/PersianData/HAM2-840421-010.ham
# ../data/PersianData/HAM2-840421-095.ham
# ../data/PersianData/HAM2-840527-064.ham
# ../data/PersianData/HAM2-840817-053.ham
# ../data/PersianData/HAM2-840712-052.ham
# ../data/PersianData/HAM2-840520-193.ham
# ../data/PersianData/HAM2-840208-015.ham
# ../data/PersianData/HAM2-840712-074.ham
# ../data/PersianData/HAM2-840208-010.ham
# ../data/PersianData/HAM2-840829-067.ham
# ../data/PersianData/HAM2-840622-064.ham
# ../data/PersianData/HAM2-840705-055.ham
# ../data/PersianData/HAM2-840330-069.ham
# ../data/PersianData/HAM2-840325-022.ham
# ../data/PersianData/HAM2-840816-103.ham
# ../data/PersianData/HAM2-840819-103.ham
# ../data/PersianData/HAM2-840720-169.ham
# ../data/PersianData/HAM2-840903-167.ham
# ../data/PersianData/HAM2-840502-126.ham
# ../data/PersianData/HAM2-840914-004.ham
# ../data/PersianData/HAM2-841006-089.ham
# ../data/PersianData/HAM2-840422-125.ham
# ../data/PersianData/HAM2-840624-123.ham
# ../data/PersianData/HAM2-840910-068.ham
# ../data/PersianData/HAM2-840527-074.ham
# ../data/PersianData/HAM2-840504-023.ham
# ../data/PersianData/HAM2-840728-117.ham
# ../data/PersianData/HAM2-840308-038.ham
# ../data/PersianData/HAM2-840607-035.ham
# ../data/PersianData/HAM2-840226-067.ham
# ../data/PersianData/HAM2-840220-031.ham
# ../data/PersianData/HAM2-840807-036.ham
# ../data/PersianData/HAM2-840505-013.ham
# ../data/PersianData/HAM2-840503-073.ham
# ../data/PersianData/HAM2-840218-050.ham
# ../data/PersianData/HAM2-840601-097.ham
# ../data/PersianData/HAM2-840302-045.ham
# ../data/PersianData/HAM2-840826-050.ham
# ../data/PersianData/HAM2-840601-096.ham
# ../data/PersianData/HAM2-840420-058.ham
# ../data/PersianData/HAM2-840506-109.ham
# ../data/PersianData/HAM2-840412-061.ham
# ../data/PersianData/HAM2-840726-070.ham
# ../data/PersianData/HAM2-840504-004.ham
# ../data/PersianData/HAM2-840307-005.ham
# ../data/PersianData/HAM2-840922-061.ham
# ../data/PersianData/HAM2-841001-144.ham
# ../data/PersianData/HAM2-840529-030.ham
# ../data/PersianData/HAM2-840623-140.ham
# ../data/PersianData/HAM2-840212-009.ham
# ../data/PersianData/HAM2-840819-167.ham
# ../data/PersianData/HAM2-840428-075.ham
# ../data/PersianData/HAM2-840702-074.ham
# ../data/PersianData/HAM2-840810-089.ham
# ../data/PersianData/HAM2-840617-111.ham
# ../data/PersianData/HAM2-840815-055.ham
# ../data/PersianData/HAM2-840906-004.ham
# ../data/PersianData/HAM2-840901-017.ham
# ../data/PersianData/HAM2-840726-034.ham
# ../data/PersianData/HAM2-841005-122.ham
# ../data/PersianData/HAM2-840930-053.ham
# ../data/PersianData/HAM2-840816-010.ham
# ../data/PersianData/HAM2-840705-153.ham
# ../data/PersianData/HAM2-840624-014.ham
# ../data/PersianData/HAM2-840709-049.ham
# ../data/PersianData/HAM2-840603-166.ham
# ../data/PersianData/HAM2-840802-183.ham
# ../data/PersianData/HAM2-840401-142.ham
# ../data/PersianData/HAM2-840807-061.ham
# ../data/PersianData/HAM2-840823-148.ham
# ../data/PersianData/HAM2-840802-113.ham
# ../data/PersianData/HAM2-840823-016.ham
# ../data/PersianData/HAM2-840818-061.ham
# ../data/PersianData/HAM2-840901-041.ham
# ../data/PersianData/HAM2-840902-059.ham
# ../data/PersianData/HAM2-840312-168.ham
# ../data/PersianData/HAM2-840328-072.ham
# ../data/PersianData/HAM2-840802-059.ham
# ../data/PersianData/HAM2-840208-059.ham
# ../data/PersianData/HAM2-840914-054.ham
# ../data/PersianData/HAM2-840927-143.ham
# ../data/PersianData/HAM2-840711-088.ham
# ../data/PersianData/HAM2-840208-036.ham
# ../data/PersianData/HAM2-840718-092.ham
# ../data/PersianData/HAM2-840808-178.ham
# ../data/PersianData/HAM2-840225-033.ham
# ../data/PersianData/HAM2-840523-013.ham
# ../data/PersianData/HAM2-840721-005.ham
# ../data/PersianData/HAM2-840825-011.ham
# ../data/PersianData/HAM2-841005-012.ham
# ../data/PersianData/HAM2-840811-143.ham
# ../data/PersianData/HAM2-840607-036.ham
# ../data/PersianData/HAM2-840714-031.ham
# ../data/PersianData/HAM2-841006-005.ham
# ../data/PersianData/HAM2-840617-167.ham
# ../data/PersianData/HAM2-840319-013.ham
# ../data/PersianData/HAM2-840725-116.ham
# ../data/PersianData/HAM2-840811-136.ham
# ../data/PersianData/HAM2-840724-065.ham
# ../data/PersianData/HAM2-840627-106.ham
# ../data/PersianData/HAM2-840922-027.ham
# ../data/PersianData/HAM2-840415-022.ham
# ../data/PersianData/HAM2-840825-092.ham
# ../data/PersianData/HAM2-840817-111.ham
# ../data/PersianData/HAM2-840524-020.ham
# ../data/PersianData/HAM2-840416-160.ham
# ../data/PersianData/HAM2-840302-136.ham
# ../data/PersianData/HAM2-840519-024.ham
# ../data/PersianData/HAM2-840829-107.ham
# ../data/PersianData/HAM2-840605-039.ham
# ../data/PersianData/HAM2-840903-059.ham
# ../data/PersianData/HAM2-840603-002.ham
# ../data/PersianData/HAM2-840331-001.ham
# ../data/PersianData/HAM2-840323-018.ham
# ../data/PersianData/HAM2-840302-142.ham
# ../data/PersianData/HAM2-840605-143.ham
# ../data/PersianData/HAM2-840901-118.ham
# ../data/PersianData/HAM2-840901-154.ham
# ../data/PersianData/HAM2-840704-020.ham
# ../data/PersianData/HAM2-840913-054.ham
# ../data/PersianData/HAM2-840724-036.ham
# ../data/PersianData/HAM2-840305-063.ham
# ../data/PersianData/HAM2-840614-091.ham
# ../data/PersianData/HAM2-841003-002.ham
# ../data/PersianData/HAM2-840706-147.ham
# ../data/PersianData/HAM2-840801-076.ham
# ../data/PersianData/HAM2-840801-056.ham
# ../data/PersianData/HAM2-840412-033.ham
# ../data/PersianData/HAM2-840910-111.ham
# ../data/PersianData/HAM2-840928-005.ham
# ../data/PersianData/HAM2-840704-089.ham
# ../data/PersianData/HAM2-840612-075.ham
# ../data/PersianData/HAM2-840412-058.ham
# ../data/PersianData/HAM2-840228-014.ham
# ../data/PersianData/HAM2-840927-088.ham
# ../data/PersianData/HAM2-840912-047.ham
# ../data/PersianData/HAM2-840418-010.ham
# ../data/PersianData/HAM2-840323-109.ham
# ../data/PersianData/HAM2-840615-058.ham
# ../data/PersianData/HAM2-840212-005.ham
# ../data/PersianData/HAM2-840829-133.ham
# ../data/PersianData/HAM2-840303-049.ham
# ../data/PersianData/HAM2-840222-074.ham
# ../data/PersianData/HAM2-840603-090.ham
# ../data/PersianData/HAM2-840825-075.ham
# ../data/PersianData/HAM2-840530-003.ham
# ../data/PersianData/HAM2-840614-002.ham
# ../data/PersianData/HAM2-840605-007.ham
# ../data/PersianData/HAM2-840311-149.ham
# ../data/PersianData/HAM2-840323-059.ham
# ../data/PersianData/HAM2-840710-048.ham
# ../data/PersianData/HAM2-840705-097.ham
# ../data/PersianData/HAM2-840616-012.ham
# ../data/PersianData/HAM2-840426-050.ham
# ../data/PersianData/HAM2-840821-108.ham
# ../data/PersianData/HAM2-840605-005.ham
# ../data/PersianData/HAM2-840804-194.ham
# ../data/PersianData/HAM2-840515-012.ham
# ../data/PersianData/HAM2-840819-027.ham
# ../data/PersianData/HAM2-840801-064.ham
# ../data/PersianData/HAM2-840630-063.ham
# ../data/PersianData/HAM2-841007-049.ham
# ../data/PersianData/HAM2-840826-063.ham
# ../data/PersianData/HAM2-840328-055.ham
# ../data/PersianData/HAM2-840817-036.ham
# ../data/PersianData/HAM2-840215-128.ham
# ../data/PersianData/HAM2-840623-002.ham
# ../data/PersianData/HAM2-840416-153.ham
# ../data/PersianData/HAM2-840804-113.ham
# ../data/PersianData/HAM2-840423-126.ham
# ../data/PersianData/HAM2-840718-093.ham
# ../data/PersianData/HAM2-841006-166.ham
# ../data/PersianData/HAM2-840609-148.ham
# ../data/PersianData/HAM2-840901-044.ham
# ../data/PersianData/HAM2-840221-061.ham
# ../data/PersianData/HAM2-840605-036.ham
# ../data/PersianData/HAM2-840724-023.ham
# ../data/PersianData/HAM2-840301-139.ham
# ../data/PersianData/HAM2-840807-090.ham
# ../data/PersianData/HAM2-840319-055.ham
# ../data/PersianData/HAM2-840923-078.ham
# ../data/PersianData/HAM2-840616-073.ham
# ../data/PersianData/HAM2-840208-035.ham
# ../data/PersianData/HAM2-840326-099.ham
# ../data/PersianData/HAM2-840304-040.ham
# ../data/PersianData/HAM2-841005-092.ham
# ../data/PersianData/HAM2-840408-108.ham
# ../data/PersianData/HAM2-840905-069.ham
# ../data/PersianData/HAM2-840818-157.ham
# ../data/PersianData/HAM2-840829-057.ham
# ../data/PersianData/HAM2-840506-012.ham
# ../data/PersianData/HAM2-840404-133.ham
# ../data/PersianData/HAM2-840408-031.ham
# ../data/PersianData/HAM2-840412-057.ham
# ../data/PersianData/HAM2-840906-130.ham
# ../data/PersianData/HAM2-840411-053.ham
# ../data/PersianData/HAM2-840520-140.ham
# ../data/PersianData/HAM2-840217-022.ham
# ../data/PersianData/HAM2-840426-111.ham
# ../data/PersianData/HAM2-840502-011.ham
# ../data/PersianData/HAM2-840605-052.ham
# ../data/PersianData/HAM2-840329-023.ham
# ../data/PersianData/HAM2-840814-119.ham
# ../data/PersianData/HAM2-840519-078.ham
# ../data/PersianData/HAM2-840221-073.ham
# ../data/PersianData/HAM2-841005-107.ham
# ../data/PersianData/HAM2-840503-084.ham
# ../data/PersianData/HAM2-840401-010.ham
# ../data/PersianData/HAM2-840628-114.ham
# ../data/PersianData/HAM2-840908-012.ham
# ../data/PersianData/HAM2-840628-018.ham
# ../data/PersianData/HAM2-840816-121.ham
# ../data/PersianData/HAM2-840519-034.ham
# ../data/PersianData/HAM2-840726-153.ham
# ../data/PersianData/HAM2-840627-072.ham
# ../data/PersianData/HAM2-840310-017.ham
# ../data/PersianData/HAM2-840412-145.ham
# ../data/PersianData/HAM2-840716-017.ham
# ../data/PersianData/HAM2-840518-071.ham
# ../data/PersianData/HAM2-840226-056.ham
# ../data/PersianData/HAM2-840509-136.ham
# ../data/PersianData/HAM2-840623-156.ham
# ../data/PersianData/HAM2-840903-028.ham
# ../data/PersianData/HAM2-840317-106.ham
# ../data/PersianData/HAM2-840627-027.ham
# ../data/PersianData/HAM2-840321-047.ham
# ../data/PersianData/HAM2-840829-001.ham
# ../data/PersianData/HAM2-840723-087.ham
# ../data/PersianData/HAM2-840501-123.ham
# ../data/PersianData/HAM2-840721-092.ham
# ../data/PersianData/HAM2-840525-027.ham
# ../data/PersianData/HAM2-840817-112.ham
# ../data/PersianData/HAM2-840212-053.ham
# ../data/PersianData/HAM2-840725-028.ham
# ../data/PersianData/HAM2-840310-130.ham
# ../data/PersianData/HAM2-840906-110.ham
# ../data/PersianData/HAM2-840310-148.ham
# ../data/PersianData/HAM2-840917-121.ham
# ../data/PersianData/HAM2-840406-030.ham
# ../data/PersianData/HAM2-840720-099.ham
# ../data/PersianData/HAM2-840301-153.ham
# ../data/PersianData/HAM2-840825-016.ham
# ../data/PersianData/HAM2-840830-061.ham
# ../data/PersianData/HAM2-840703-032.ham
# ../data/PersianData/HAM2-840326-038.ham
# ../data/PersianData/HAM2-840906-014.ham
# ../data/PersianData/HAM2-840913-097.ham
# ../data/PersianData/HAM2-840823-110.ham
# ../data/PersianData/HAM2-840513-058.ham
# ../data/PersianData/HAM2-840506-172.ham
# ../data/PersianData/HAM2-840814-048.ham
# ../data/PersianData/HAM2-840504-042.ham
# ../data/PersianData/HAM2-840304-106.ham
# ../data/PersianData/HAM2-840418-045.ham
# ../data/PersianData/HAM2-840804-070.ham
# ../data/PersianData/HAM2-840628-041.ham
# ../data/PersianData/HAM2-840227-129.ham
# ../data/PersianData/HAM2-840323-007.ham
# ../data/PersianData/HAM2-840606-122.ham
# ../data/PersianData/HAM2-840706-005.ham
# ../data/PersianData/HAM2-840218-080.ham
# ../data/PersianData/HAM2-840923-023.ham
# ../data/PersianData/HAM2-840402-076.ham
# ../data/PersianData/HAM2-840421-097.ham
# ../data/PersianData/HAM2-840226-111.ham
# ../data/PersianData/HAM2-840326-086.ham
# ../data/PersianData/HAM2-840802-108.ham
# ../data/PersianData/HAM2-840211-014.ham
# ../data/PersianData/HAM2-840429-083.ham
# ../data/PersianData/HAM2-840328-020.ham
# ../data/PersianData/HAM2-840319-115.ham
# ../data/PersianData/HAM2-840606-124.ham
# ../data/PersianData/HAM2-841006-070.ham
# ../data/PersianData/HAM2-840923-014.ham
# ../data/PersianData/HAM2-840416-053.ham
# ../data/PersianData/HAM2-840801-057.ham
# ../data/PersianData/HAM2-840919-121.ham
# ../data/PersianData/HAM2-840704-063.ham
# ../data/PersianData/HAM2-840224-046.ham
# ../data/PersianData/HAM2-840811-115.ham
# ../data/PersianData/HAM2-840804-081.ham
# ../data/PersianData/HAM2-840508-137.ham
# ../data/PersianData/HAM2-840616-005.ham
# ../data/PersianData/HAM2-840727-157.ham
# ../data/PersianData/HAM2-840322-054.ham
# ../data/PersianData/HAM2-841008-151.ham
# ../data/PersianData/HAM2-840804-030.ham
# ../data/PersianData/HAM2-840527-193.ham
# ../data/PersianData/HAM2-840626-073.ham
# ../data/PersianData/HAM2-840819-125.ham
# ../data/PersianData/HAM2-840912-120.ham
# ../data/PersianData/HAM2-840606-036.ham
# ../data/PersianData/HAM2-840817-004.ham
# ../data/PersianData/HAM2-840325-107.ham
# ../data/PersianData/HAM2-840612-111.ham
# ../data/PersianData/HAM2-841006-035.ham
# ../data/PersianData/HAM2-840805-093.ham
# ../data/PersianData/HAM2-840423-059.ham
# ../data/PersianData/HAM2-840815-064.ham
# ../data/PersianData/HAM2-840804-178.ham
# ../data/PersianData/HAM2-840808-038.ham
# ../data/PersianData/HAM2-840531-049.ham
# ../data/PersianData/HAM2-840723-086.ham
# ../data/PersianData/HAM2-840816-092.ham
# ../data/PersianData/HAM2-840720-083.ham
# ../data/PersianData/HAM2-840712-099.ham
# ../data/PersianData/HAM2-840702-068.ham
# ../data/PersianData/HAM2-840213-031.ham
# ../data/PersianData/HAM2-840624-058.ham
# ../data/PersianData/HAM2-840807-134.ham
# ../data/PersianData/HAM2-840609-122.ham
# ../data/PersianData/HAM2-840817-138.ham
# ../data/PersianData/HAM2-840914-045.ham
# ../data/PersianData/HAM2-840415-030.ham
# ../data/PersianData/HAM2-840406-024.ham
# ../data/PersianData/HAM2-840724-055.ham
# ../data/PersianData/HAM2-840714-127.ham
# ../data/PersianData/HAM2-840131-006.ham
# ../data/PersianData/HAM2-840422-059.ham
# ../data/PersianData/HAM2-840515-088.ham
# ../data/PersianData/HAM2-840713-084.ham
# ../data/PersianData/HAM2-840523-076.ham
# ../data/PersianData/HAM2-840503-137.ham
# ../data/PersianData/HAM2-840506-169.ham
# ../data/PersianData/HAM2-840910-168.ham
# ../data/PersianData/HAM2-840624-016.ham
# ../data/PersianData/HAM2-840614-063.ham
# ../data/PersianData/HAM2-840329-084.ham
# ../data/PersianData/HAM2-840802-064.ham
# ../data/PersianData/HAM2-840524-012.ham
# ../data/PersianData/HAM2-840530-139.ham
# ../data/PersianData/HAM2-840331-006.ham
# ../data/PersianData/HAM2-840318-099.ham
# ../data/PersianData/HAM2-840712-112.ham
# ../data/PersianData/HAM2-840703-070.ham
# ../data/PersianData/HAM2-840321-121.ham
# ../data/PersianData/HAM2-840910-056.ham
# ../data/PersianData/HAM2-840311-116.ham
# ../data/PersianData/HAM2-840214-049.ham
# ../data/PersianData/HAM2-840809-122.ham
# ../data/PersianData/HAM2-840804-112.ham
# ../data/PersianData/HAM2-840828-026.ham
# ../data/PersianData/HAM2-840312-058.ham
# ../data/PersianData/HAM2-840712-005.ham
# ../data/PersianData/HAM2-840921-024.ham
# ../data/PersianData/HAM2-840608-158.ham
# ../data/PersianData/HAM2-840624-069.ham
# ../data/PersianData/HAM2-840711-112.ham
# ../data/PersianData/HAM2-840606-088.ham
# ../data/PersianData/HAM2-840816-044.ham
# ../data/PersianData/HAM2-840309-118.ham
# ../data/PersianData/HAM2-840428-102.ham
# ../data/PersianData/HAM2-840516-005.ham
# ../data/PersianData/HAM2-840411-125.ham
# ../data/PersianData/HAM2-840910-023.ham
# ../data/PersianData/HAM2-841001-023.ham
# ../data/PersianData/HAM2-840208-102.ham
# ../data/PersianData/HAM2-840805-152.ham
# ../data/PersianData/HAM2-840231-105.ham
# ../data/PersianData/HAM2-840929-153.ham
# ../data/PersianData/HAM2-840511-049.ham
# ../data/PersianData/HAM2-841008-085.ham
# ../data/PersianData/HAM2-840405-048.ham
# ../data/PersianData/HAM2-841003-090.ham
# ../data/PersianData/HAM2-840728-157.ham
# ../data/PersianData/HAM2-840520-085.ham
# ../data/PersianData/HAM2-840809-058.ham
# ../data/PersianData/HAM2-840928-035.ham
# ../data/PersianData/HAM2-840220-055.ham
# ../data/PersianData/HAM2-840909-089.ham
# ../data/PersianData/HAM2-840227-121.ham
# ../data/PersianData/HAM2-840627-139.ham
# ../data/PersianData/HAM2-840805-101.ham
# ../data/PersianData/HAM2-840226-013.ham
# ../data/PersianData/HAM2-840519-096.ham
# ../data/PersianData/HAM2-840906-001.ham
# ../data/PersianData/HAM2-840308-098.ham
# ../data/PersianData/HAM2-840527-160.ham
# ../data/PersianData/HAM2-840212-019.ham
# ../data/PersianData/HAM2-841001-037.ham
# ../data/PersianData/HAM2-840816-051.ham
# ../data/PersianData/HAM2-840903-007.ham
# ../data/PersianData/HAM2-840627-138.ham
# ../data/PersianData/HAM2-840704-017.ham
# ../data/PersianData/HAM2-840502-150.ham
# ../data/PersianData/HAM2-840325-115.ham
# ../data/PersianData/HAM2-840914-055.ham
# ../data/PersianData/HAM2-840513-182.ham
# ../data/PersianData/HAM2-840413-148.ham

# %%
print(stop_words)
# Out:
# ['در', 'به', '.', 'از', 'این', 'که', 'را', '#است', 'با', 'شد#شو', 'کرد#کن', 'آن', ':', 'برای', 'یک', 'بود#باش', 'کشور', 'شده', 'داشت#دار', 'سال', 'خود', 'ایران', 'تا', 'گفت#گو', 'بر', 'نیز', 'خواست#خواه', 'هم', 'دیگر', 'داد#ده', 'اما', 'توانست#توان', 'یا', 'درصد', 'گرفت#گیر', ')', 'کار', 'وی', '(', '«', 'هر', 'باید', '»', 'قرار', 'ما', 'شرکت', 'روز', 'حال', 'مورد']

# %%
def normalize(sentence):
    sentence = normalizer.normalize(sentence)
    tokens = nltk.word_tokenize(sentence)
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# %%
sentence = input("Enter the sentence you want to be cleaned:")
sentence = ' '.join(normalize(sentence))
print(sentence)
# Out:
# ['شتر',
#  'برایم',
#  'ارمغان',
#  'آورد#آور',
#  'ای',
#  'ملعون',
#  'دست',
#  'و',
#  'پا',
#  'چلفتی']

# %%
#constructing the posting list 
path = "../data/PersianData"
pl = {}
docs = []
for file in os.listdir(path):
    docs.append(file)
    filename = os.path.join(path, file)
    with open(filename) as f:
        lines = f.readlines()
        line = ' '.join(lines)
        tks = normalize(line)
        for n, tk in enumerate(tks):
            tmp = (file, n)
            if tk in pl:
                pl[tk].append(tmp)
            else:
                pl[tk] = [tmp]
                
terms = [term for term,_ in pl.items()]
term_index = {}
for i,term in enumerate(terms):
    term_index[term] = i

# %%
bigram = {}
for token in [kv[0] for kv in pl.items()]:
    for n, ch in enumerate(token[:-1]):
        bi = token[n]+token[n+1]
        if(bi in bigram):
            bigram[bi].append(token)
        else:
            bigram[bi]=[token]

# %%
#correcting the word in the queries
sl = 0
wl = {}
def correct_word(w):
    for n, ch in enumerate(w[:-1]):
        bi = w[n]+w[n+1]
        for word in bigram[bi]:
            if word in wl:
                wl[word] = wl[word] + 1
            else:
                wl[word] = 1
    candids = []
    for word, n in wl.items():
        if n > sl:
            candids.append(word)
    distances = [edit_distance(candid,w) for candid in candids]
    candids = [candid for _,candid in sorted(zip(distances,candids))]
    print(candids[0:5])

# %%
query = input("Enter the query you want to be corrected:")
for token in nltk.word_tokenize(query):
    correct_word(token)
# Out:
# Enter the query you want to be corrected:سلا کرد مهد
# ['سلا', 'آلا', 'الا', 'بلا', 'دلا']
# ['آرد', 'برد', 'ترد', 'خرد', 'درد']
# ['مهد', 'جهد', 'عهد', 'فهد', 'مرد']

# %%
idf={}
for term,posting_list in pl.items(): #calculate idf, idf is a sign of how important a term is
    idf[term] = math.log(len(docs)/(len(posting_list)))
tfidf={} #dictionary from doc to its corresponding vector
for doc in docs:
    tfidf[doc] = [0 for term in terms]
    
for term, posting_list in pl.items():
    for doc_pos in posting_list:
        doc = doc_pos[0]
        tfidf[doc][term_index[term]] += 1

for doc in docs:
    tfidf[doc] = [ 1+math.log(tf) if tf > 0 else 0 for tf in tfidf[doc]]
    doc_len = math.sqrt(sum([x*x for x in tfidf[doc]]))
    if doc_len != 0:
        tfidf[doc] = [x/doc_len for x in tfidf[doc]]

# %%
def query_2_vec(query):
    tks = normalize(query)
    vec = [0 for term in terms]
    for term in tks:
        vec[term_index[term]]+= 1
    vec = [ 1+math.log(tf) if tf > 0 else 0 for tf in vec]
    for term in tks:
        vec[term_index[term]] = vec[term_index[term]]*idf[term]
    query_len = math.sqrt(sum([x*x for x in vec]))
    if query_len != 0:
        vec = [x/query_len for x in vec]
    return vec

def cosine(v, u):
    ans = sum([v[i] * u[i] for i in range(len(v))])
    return ans
    
def search_vec(vec):
    global tfidf, docs
    cosines = [-1 * cosine(vec, tfidf[doc]) for doc in docs]
    ans = [doc for _,doc in sorted(zip(cosines, docs))]
    return ans


def show_doc(file):
    filename = os.path.join(path, file)
    with open(filename) as f:
        lines = f.readlines()
        line = ' '.join(lines)
        print(line)

# %%
query = input("Enter the query you want to search for:")
vec = query_2_vec(query)
ans = search_vec(vec)
show_doc(ans[0])
# Out:
# Enter the query you want to search for:خورشید کشت
# درياهاي سمي پيش از تكامل زمين
#  گروه دانش و فناوري ـ زهرا بخشي: محققان ناسا اعلام كرده اند در گذشته هاي دور در درياهاي زمين گوگرد فراواني وجود داشته و اين گوگرد مانع زندگي گسترده حيواناتي مانند ماهي ها و پستانداران بوده است. گروهي از دانشمندان ام آي تي به همراه همكارانشان از استراليا و بريتانيا، فسيل هاي 6/1 ميليارد سالي رنگيزهاي فتوسنتزي مك آرتور بيسين واقع در شمال استراليا را مورد بررسي قرار داده اند. طي اين پژوهش، آن ها باكتري هاي فتوسنتزي را يافته اند كه براي زندگي احتياج زيادي به گوگرد و نور خورشيد داشته اند. اين باكتري ها به علت رنگيزهايشان معروف به باكتري هاي سولفوري بنفش و سبز هستند. اين ميكروب هاي تك سلولي فقط در محيط هاي غني از گوگرد و نور خورشيد مي توانند زندگي كنند. محققان همچنين مقدار كمي جلبك و اكسيژن در اين فسيل ها يافته اند كه باكتري هاي بنفش رنگ را توليد مي كنند. دانشمندان بر اين باورند كه علت نايابي نسبي اين موجودات زنده، سمي بودن آن ها با گوگرد است. دكتر كارل پيچر، دانشمند و زيست شناس مي گويد: اين تحقيق نشان مي دهد كه درياهاي زمين تا چندي پيش محيط هاي ناسازگاري براي زندگي حيوانات و گياهان بوده اند، و اين احتمالا تأثير زيادي در شكل گيري دنياي مدرن امروز داشته  است.
#  راجر سامونز، پروفسور زمين شناسي ام آي تي مي گويد: كشف رنگيزهاي فسيل شده باكتري هاي سولفوربنفش بسيار جديد و تصادفي بوده است، زيرا اين باكتري ها براي زندگي، نياز فراواني به حرارت خورشيد و منبع وسيعي از گوگرد دارند و دسترسي به آن ها اصلا آسان نبوده است. گوگرد لازم براي اين موجودات، احتمالا از احياي سولفات منتقل شده به دريا از طريق صخره هاي در معرض هوا، توسط نوعي باكتري توليد مي شده است.
#  جاچن بروكس، عضو اين گروه تحقيقاتي مي گويد: فسيل هاي صخره هاي مك آرتور بيسين طي ميليون ها سال و در منطقه وسيعي به جا مانده اند، بنابراين احتمال تشكيل آن ها زير درياها بسيار زياد است. اين نتيجه نشان مي دهد كه در درياها مقدار زيادي سولفيد هيدروژن وجود داشته و اين براي موجودات زنده بسيار خطرناك بوده است. در واقع در هفت هشتم تاريخ 5/4 ميليارد سالي زمين، مقدار كمي اكسيژن براي زندگي موجودات زيردريايي اكسيژن زي وجود داشته است.
#  اين تحقيق ادامه تلاش ناسا و مؤسسات ديگر در شناخت تاريخ اخير زمين بوده است و در آزمايشگاه ساموتر انجام شده است و اعضاي اين گروه جاچن بروكس از دانشگاه بين المللي استراليا، گوردون  لاو از ام آي تي، استفن بُدِن از دانشگاه بردين اسكاتلند، گراهام لوگان از دانشگاه زمين شناسي استراليا و اندرو نال از دانشگاه  هاروارد بوده اند.
#  منبع: spaceflightnow.com
